# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Welcome to Colab!</h1>
# </div>
#
# <div class="markdown-google-sans">
#   <h2>Explore the Gemini API</h2>
#   <p>The Gemini API gives you access to Gemini models created by Google DeepMind. Gemini models are built from the ground up to be multimodal, so you can reason seamlessly across text, images, code, and audio.
#   </p>
#   <strong>How to get started</strong>
#     <ol>
#       <li>Go to <a href="https://aistudio.google.com/">Google AI Studio</a> and log in with your Google account.</li>
#       <li><a href="https://aistudio.google.com/app/apikey">Create an API key</a>.</li>
#       <li>Use a quickstart for <a href="https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Prompting.ipynb">Python</a>, or call the REST API using <a href="https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/rest/Prompting_REST.ipynb">curl</a>.</li>
#       </ol>
#   <strong>Explore use cases</strong>
#     <ul>
#       <li><a href="https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Market_a_Jet_Backpack.ipynb">Create a marketing campaign</a></li>
#       <li><a href="https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Audio.ipynb">Analyze audio recordings</a></li>
#       <li><a href="https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/System_instructions.ipynb">Use System instructions in chat</a></li>
#     </ul>
#   <p>To learn more, check out the <a href="https://github.com/google-gemini/cookbook">Gemini cookbook</a> or visit the <a href="https://ai.google.dev/docs/">Gemini API documentation</a>.
#   </p>
# </div>

# %% [markdown]
# If you're already familiar with Colab, check out this video to learn about interactive tables, the executed code history view, and the command palette.
#
# <center>
#   <a href="https://www.youtube.com/watch?v=rNgswRZ2C1Y" target="_blank">
#   <img alt='Thumbnail for a video showing 3 cool Google Colab features' src="data:image/png;base64,..." height="188" width="336">
#   </a>
# </center>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h2>What is Colab?</h2>
# </div>
#
# Colab, or "Colaboratory", allows you to write and execute Python in your browser, with
# - Zero configuration required
# - Access to GPUs free of charge
# - Easy sharing
#
# Whether you're a **student**, a **data scientist** or an **AI researcher**, Colab can make your work easier. Watch [Introduction to Colab](https://www.youtube.com/watch?v=inN8seMm7UI) to learn more, or just get started below!

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## **Getting started**
# </div>
#
# The document you are reading is not a static web page, but an interactive environment called a **Colab notebook** that lets you write and execute code.
#
# For example, here is a **code cell** with a short Python script that computes a value, stores it in a variable, and prints the result:

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Data science
# </div>
#
# With Colab you can harness the full power of popular Python libraries to analyze and visualize data. The code cell below uses **numpy** to generate some random data, and uses **matplotlib** to visualize it. To edit the code, just click the cell and start editing.

# %% [markdown]
# # Loading Model

# %%
# !pip install transformers==4.37.2 optimum==1.12.0 --quiet
# !pip install auto-gptq --extra-index-url https://huggingface.github.io/autogptq-index/whl/cu118/ --quiet
# !pip install langchain==0.1.9 --quiet
# !pip install chromadb
# !pip install sentence_transformers==2.4.0 --quiet
# !pip install unstructured --quiet
# !pip install pdf2image --quiet
# !pip install pdfminer.six==20221105 --quiet
# !pip install unstructured-inference --quiet
# !pip install faiss-gpu==1.7.2 --quiet
# !pip install pikepdf==8.13.0 --quiet
# !pip install pypdf==4.0.2 --quiet
# !pip install pillow_heif==0.15.0 --quiet
# !pip install bs4
# !pip install jq
# !pip install tqdm
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 30.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.6/380.6 kB 28.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 79.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.1/542.1 kB 57.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 74.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 113.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 64.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 128.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 103.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 12.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 112.7 MB/s eta 0:00:00
# ...

# %%
# Use a pipeline as a high-level helper
from langchain.llms import HuggingFacePipeline
from transformers import AutoModelForCausalLM, AutoTokenizer, GenerationConfig, pipeline
from transformers import AutoModelForSeq2SeqLM

model_name = "google/flan-t5-xl"
tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast = True)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name,device_map="auto")

gen_cfg = GenerationConfig.from_pretrained(model_name)


# model_name = "TheBloke/Llama-2-7b-Chat-GPTQ"

# model = AutoModelForCausalLM.from_pretrained(model_name,
#                                              device_map="auto",
#                                              trust_remote_code=True)

# tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast=True)

# gen_cfg = GenerationConfig.from_pretrained(model_name)

gen_cfg.max_new_tokens=100
# gen_cfg.temperature=0.0000001 # 0.0
# gen_cfg.return_full_text=True
# gen_cfg.do_sample=True
gen_cfg.repetition_penalty=1.5

pipe = pipeline(task="text2text-generation", model=model, tokenizer=tokenizer,
    generation_config=gen_cfg)
llm = HuggingFacePipeline(pipeline=pipe)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# ...

# %% [markdown]
# # KNN few shot

# %%
import os
import json
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity



def read_QA_data(file):
    with open(file) as f:
        data = json.load(f)

    return data

class KnnSearch:
    def __init__(self,data=None, num_trees=None,emb_dim=None):
        self.num_trees=num_trees
        self.emb_dim=emb_dim
    def get_embeddings_for_data(self, data_ls):
        model = SentenceTransformer('sentence-transformers/all-mpnet-base-v2')
        embeddings = model.encode(data_ls)
        return embeddings

    def get_top_n_neighbours(self,sentence,data_emb,train_data,k):
        sent_emb = self.get_embeddings_for_data(sentence)
        #data_emb = self.get_embeddings_for_data(transfer_questions)
        top_questions = []

        # print("new_emb", sent_emb.shape, data_emb.shape)
        text_sims = cosine_similarity(data_emb,[sent_emb]).tolist()
        results_sims = zip(range(len(text_sims)), text_sims)
        sorted_similarities = sorted(results_sims, key=lambda x: x[1], reverse=True)

        #print("text_sims",sorted_similarities[:2])
        for idx, item in sorted_similarities[:k]:
                #if item[0] > 0.45:
                    top_questions.append(train_data[idx])

        return top_questions

def get_questions(train_data):
    train_questions = []
    for index, data in enumerate(train_data):
        train_questions.append(data["question"])
    return train_questions

def get_prompts(exemplars,k):
    prompt = ""
    for index, data in enumerate(exemplars):
        # prompt+="[Question {}]: ".format(index+1)+ data["question"]+"\n"
        if index+1<=k:
          prompt+="Example {}: ".format(index+1)+"\n"
          prompt+= data["question"]+"\n"
          answer = ""
          for ind, subans in enumerate(data["answers"]):
            answer+=subans
            if(ind+1 < len(data["answers"])):
              answer+=', '
          # prompt+="[Answer {}]: ".format(index+1)+ answer+"\n"
          prompt+= answer+"\n"
        else:
          break

    # print("prompt§§§§",prompt)
    return prompt

train_data = read_QA_data("train_TLQA.json")
test_data = read_QA_data("test_TLQA.json")

# %%
knn_instance = KnnSearch()

train_questions = get_questions(train_data)
data_emb = knn_instance.get_embeddings_for_data(train_questions)

def few_shot_input(query, data_emb, train_data, k):
  exemplars = knn_instance.get_top_n_neighbours(query,data_emb,train_data,k)
  # prompt_question = get_prompts(exemplars)
  return exemplars
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# Testing the performance of fewshot+flanT5 without RAG
# Don't need to run it



# from langchain_core.prompts import ChatPromptTemplate

# for num_id in range(20):
#   query = test_data[num_id]['question']
#   answers = test_data[num_id]['final_answers']
#   print(query+'\n')
#   print(process_answer(answers)+'\n')
#   prompt_question = get_prompts(few_shot_input(query, data_emb, train_data, 5),5)
#   # print(prompt_question+'\n')

#   prompt = ChatPromptTemplate.from_messages([
#       ("system", "You are a intelligent Q&A machine."),
#       ("user", "Here are some examples of Q&A task: {prompt_question}. Follow the given examples and out the answer for [Question]: {test_question}")
#   ])
#   chain = prompt | llm
#   result = chain.invoke({"prompt_question":prompt_question, "test_question":query})
#   print(result)
# Out:
# List all sports teams Anthony Grant, also known as Anthony Paul Shaun Andrew Daure Grant, played for from 2010 to 2020.
#
# Southend United F.C. (2010, 2011, 2012) Stevenage F.C. (2012, 2013) Crewe Alexandra F.C. (2013, 2014, 2015) Port Vale F.C. (2015, 2016, 2017, 2018, 2019, 2020)
#
# Manchester United F.C. (2010, 2011), West Ham United F.C. (2010, 2011), Liverpool F.C. (2011, 2012, 2013, 2014), Everton F.C. (2012, 2013), Southampton F.C. (2012, 2013), Newcastle United F.C. (2012, 2013), Sunderland F.C. (2012, 2013), Aston Villa F.C. (2012, 2013), Hull City F.C.
# List all positions Oleksandr Turchynov, also known as Oleksandr Valentynovych Turchynov, held from 2010 to 2020.
#
# Prime Minister of Ukraine (2010) First Deputy Prime Minister of Ukraine (2010) People's Deputy of Ukraine (2012, 2013, 2014, 2015) Chairman of the Verkhovna Rada (2014, 2015, 2016, 2017, 2018, 2019, 2020) President of Ukraine (2014)
# ...

# %% [markdown]
# # Crawling

# %%
# from bs4 import BeautifulSoup
# import requests
# import json

# def crawler_summary(id):

#   url = "https://www.wikidata.org/wiki/{}".format(id)
#   response = requests.get(url)
#   soup = BeautifulSoup(response.content, "html.parser")
#   wiki_url = soup.find("li", attrs={"data-wb-siteid":"enwiki"})

#   if(not wiki_url):
#       print("No wikipedia page found for this entity")
#       full_page_content = "No wikipedia page found for this entity"
#   else:
#       wiki_url = wiki_url.find('a')['href']
#       if(wiki_url):
#           response = requests.get(wiki_url)
#           soup = BeautifulSoup(response.content, "html.parser")

#           content_div = soup.find(id="mw-content-text")
#           # extract all paragraphs of content
#           paras = content_div.find_all('p')

#           # concatenate paragraphs into full page content
#           full_page_content = ""
#           for para in paras:
#             full_page_content += para.text

#       else:
#           print("No wikipedia page found for this entity")
#           full_page_content = "No wikipedia page found for this entity"
#   return full_page_content

# %% [markdown]
# # Wiki Downloading

# %%
# import os
# import json
# import pandas as pd

# from tqdm import tqdm

# def read_QA_data(file):
#     with open(file) as f:
#         data = json.load(f)

#     return data

# train_data = read_QA_data("train_TLQA.json")
# test_data = read_QA_data("test_TLQA.json")

# RAG_matrix = []
# for i in tqdm(range(len(test_data))):
#   wikiid = test_data[i]['wikidata_ID']
#   RAG_matrix.append(crawler_summary(wikiid))

# print(len(RAG_matrix))

# json_data = {"info":RAG_matrix}
# filename = "RAG.json"
# with open(filename, 'w') as json_file:
#   json.dump(json_data, json_file, indent=4)
# Out:
#  41%|████      | 436/1071 [07:10<11:27,  1.08s/it]
# No wikipedia page found for this entity
#  58%|█████▊    | 619/1071 [10:06<05:25,  1.39it/s]
# No wikipedia page found for this entity
#  60%|██████    | 645/1071 [10:31<06:11,  1.15it/s]
# No wikipedia page found for this entity
#  67%|██████▋   | 720/1071 [11:48<03:56,  1.48it/s]
# No wikipedia page found for this entity
#  86%|████████▌ | 917/1071 [15:04<01:43,  1.49it/s]
# No wikipedia page found for this entity
#  96%|█████████▌| 1027/1071 [16:49<00:33,  1.32it/s]
# No wikipedia page found for this entity
# 100%|██████████| 1071/1071 [17:40<00:00,  1.01it/s]
# 1071

# %% [markdown]
# # Evaluation

# %%
import re
import string
from collections import Counter

def process_answer(answers):
  final_answer = ""
  for answer in answers:
    final_answer+= (answer+' ')

  return final_answer


def normalize_answer(s):
    """
    Lower text and remove punctuation, articles and extra whitespace.

    Args:
        s: String to normalize.

    Returns:
        Cleaned string with lowercase, no punctuations, no articles, and
            and extraneous whitespace.
    """

    def remove_articles(text):
        return re.sub(r'\b(a|an|the)\b', ' ', text)

    def white_space_fix(text):
        return ' '.join(text.split())

    def remove_punc(text):
        exclude = set(string.punctuation)
        return ''.join(ch for ch in text if ch not in exclude)

    def lower(text):
        return text.lower()

    return white_space_fix(remove_articles(remove_punc(lower(s))))


def f1_score(prediction, ground_truth):
    """Calculates F1 score.

    Args:
        prediction: Predicted answer span (string).
        ground_truth: True answer span (string).

    Returns:
        F1 score.
    """
    prediction_tokens = normalize_answer(prediction).split()

    ground_truth = process_answer(ground_truth)
    ground_truth_tokens = normalize_answer(ground_truth).split()
    common = Counter(prediction_tokens) & Counter(ground_truth_tokens)
    num_same = sum(common.values())
    if num_same == 0:
        return 0
    precision = 1.0 * num_same / len(prediction_tokens)
    recall = 1.0 * num_same / len(ground_truth_tokens)
    f1 = (2 * precision * recall) / (precision + recall)
    return f1

def exact_match_score(prediction, ground_truth):
    """Calculates exact match (EM) score.

    Args:
        prediction: Predicted answer span (string).
        ground_truth: True answer span (string).

    Returns:
        EM score.
    """
    ground_truth = process_answer(ground_truth)
    return (normalize_answer(prediction) == normalize_answer(ground_truth))

# %% [markdown]
# # RAG

# %%
from langchain.vectorstores.utils import filter_complex_metadata
from langchain.schema.document import Document
from langchain_community.document_loaders import JSONLoader
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS

def db_generate(text):

  text_splitter = RecursiveCharacterTextSplitter(chunk_size=512, chunk_overlap=64)
  # chunked_web_doc = text_splitter.split_documents(updated_web_doc)
  # print(len(chunked_web_doc))

  chunked_web_doc = [Document(page_content=x) for x in text_splitter.split_text(text)]

  embeddings = HuggingFaceEmbeddings()

  db_web = FAISS.from_documents(chunked_web_doc, embeddings)
  return db_web

# %%
from langchain.prompts import PromptTemplate
from langchain.chains import RetrievalQA
from tqdm import tqdm
from textwrap import fill
import json
import warnings
warnings.filterwarnings("ignore")


################################
#RAG without fewshot
################################

prompt_template = """
Please answer the question based on the CONTEXT provided. Do not use any other information. If you can't find the relevant information in the context, just say you don't have enough information to answer the question. Don't try to make up an answer.
CONTEXT:{context}
QUESTION: {question}
"""

prompt = PromptTemplate(template=prompt_template, input_variables=["context", "question"])

with open('RAG.json') as f:
    d = json.load(f)
    RAG_data = d['info']

RAG_predict = [[],[],[],[]]

K_candidate = [3,5,7,10]

for i in tqdm(range(len(test_data))):
  query = test_data[i]['question']

  answers = test_data[i]['answers']
  print('\n' + process_answer(answers))

  db_web = db_generate(RAG_data[i])
  # avoid generating the same db_web repeatly
  for j in range(len(K_candidate)):
    Chain_web = RetrievalQA.from_chain_type(
        llm=llm,
        chain_type="stuff",
        retriever=db_web.as_retriever(search_kwargs={'k': K_candidate[j]}), # (search_kwargs={'k': 5, 'score_threshold': 0.8}),
        chain_type_kwargs={"prompt": prompt},
    )

    result = Chain_web.invoke(query)

    print('\n' + result['result'])
    RAG_predict[j].append(result['result'])

# save the prediction result in the json file
for k in range(len(K_candidate)):
  json_data = {"info":RAG_predict[k]}
  filename = "predictions_top{}_RAG_flanLarge.json".format(K_candidate[k])
  with open(filename, 'w') as json_file:
    json.dump(json_data, json_file, indent=4)
# Out:
#   0%|          | 0/1071 [00:00<?, ?it/s]
# Southend United F.C. (2010, 2011, 2012) Stevenage F.C. (2012, 2013) Crewe Alexandra F.C. (2013, 2014, 2015) Port Vale F.C. (2015, 2016, 2017, 2018, 2019, 2020)
# Token indices sequence length is longer than the specified maximum sequence length for this model (659 > 512). Running this sequence through the model will result in indexing errors
# Swindon Town
#
# Swindon Town
#
# Swindon Town
#   0%|          | 1/1071 [00:07<2:04:57,  7.01s/it]
# Swindon Town
#
# Prime Minister of Ukraine (2010) First Deputy Prime Minister of Ukraine (2010) People's Deputy of Ukraine (2012, 2013, 2014, 2015) Chairman of the Verkhovna Rada (2014, 2015, 2016, 2017, 2018, 2019, 2020) President of Ukraine (2014)
#
# First Vice Prime Minister
#
# First Vice Prime Minister
#
# First Vice Prime Minister
#   0%|          | 2/1071 [00:13<1:58:05,  6.63s/it]
# First Vice Prime Minister
#
# ...

# %%
from langchain.prompts import PromptTemplate
from langchain.chains import RetrievalQA
from tqdm import tqdm
from textwrap import fill
import json
import warnings
warnings.filterwarnings("ignore")

################################
#RAG with fewshot
################################

with open('RAG.json') as f:
    d = json.load(f)
    RAG_data = d['info']

RAG_predict = [[],[],[],[]]

for i in tqdm(range(len(test_data))):
  query = test_data[i]['question']

  answers = test_data[i]['answers']
  print('\n' + process_answer(answers))

  db_web = db_generate(RAG_data[i])


  fewshot = [3,5,7,10]
  exemplars = few_shot_input(query, data_emb, train_data, 10)

  for i in range(len(fewshot)):

    prompt_question = get_prompts(exemplars,fewshot[i])
    prompt_template = """
    Please answer the QUESTION based on the CONTEXT provided. Ensure that your answer follows the same format as provided in the EXAMPLES. Do not use any other information. If you can't find the relevant information in the CONTEXT, just say you don't have enough information to answer the QUESTION. Don't try to make up an answer.
    CONTEXT:
    {context}
    EXAMPLES:
    {instruction}
    QUESTION: {question}
    """.format(context = "{context}", instruction = prompt_question, question = "{question}")

    prompt = PromptTemplate(template=prompt_template, input_variables=["context", "question"])

    Chain_web = RetrievalQA.from_chain_type(
          llm=llm,
          chain_type="stuff",
          retriever=db_web.as_retriever(search_kwargs={'k': 5}), # (search_kwargs={'k': 5, 'score_threshold': 0.8}),
          chain_type_kwargs={"prompt": prompt},
      )

    result = Chain_web.invoke(query)

    print('\n' + result['result'])
    RAG_predict[i].append(result['result'])

for k in range(len(fewshot)):
  json_data = {"info":RAG_predict[k]}
  filename = "predictions_top5_RAG_fewshot{}_flanXl.json".format(fewshot[k])
  with open(filename, 'w') as json_file:
      json.dump(json_data, json_file, indent=4)
# Out:
#   0%|          | 0/1071 [00:00<?, ?it/s]
# Southend United F.C. (2010, 2011, 2012) Stevenage F.C. (2012, 2013) Crewe Alexandra F.C. (2013, 2014, 2015) Port Vale F.C. (2015, 2016, 2017, 2018, 2019, 2020)
#
# Welling United.
#
# Welling United.
#
# Welling United.
#   0%|          | 1/1071 [00:10<3:03:43, 10.30s/it]
# Welling United.
#
# Prime Minister of Ukraine (2010) First Deputy Prime Minister of Ukraine (2010) People's Deputy of Ukraine (2012, 2013, 2014, 2015) Chairman of the Verkhovna Rada (2014, 2015, 2016, 2017, 2018, 2019, 2020) President of Ukraine (2014)
#
# First Vice Prime Minister.
#
# First Vice Prime Minister.
#
# First Vice Prime Minister.
#   0%|          | 2/1071 [00:20<3:00:50, 10.15s/it]
# First Vice Prime Minister.
#
# Socialist Party (2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019) RISE (Ireland) (2019, 2020)
#
# People Before Profit–Solidarity.
#
# People Before Profit–Solidarity.
#
# People Before Profit–Solidarity.
# ...

# %%
json_data = {"info":RAG_predict}
filename = "predictions_top3RAG_flanXl.json"
with open(filename, 'w') as json_file:
  json.dump(json_data, json_file, indent=4)

# %%
EM_total = 0
F1_total = 0
for i in range(len(RAG_predict[0])):
  EM_total+=exact_match_score(RAG_predict[3][i], test_data[i]['final_answers'])
  F1_total+=f1_score(RAG_predict[3][i], test_data[i]['final_answers'])

print('Exact Match: ', EM_total/len(test_data))
print('F1 Score: ', F1_total/len(test_data))
# Out:
# Exact Match:  0.0
# F1 Score:  0.1622151896861925
